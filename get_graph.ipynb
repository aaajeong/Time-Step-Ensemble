# %%
from matplotlib import pyplot as plt
import numpy as np

# %% [markdown]
# ### 각 모델 TQE 그래프 출력

# %%
x_values = np.arange(5)


esb_list = [0.562828, 0.713631, 0.738431, 0.74431, 0.745056]  # soft voting
sur_list = [0.555392, 0.694859, 0.722767, 0.726349, 0.731033] # survival
maj_list = [0.539709, 0.680405, 0.711867, 0.719765, 0.724257] # majority

# model_1 = [0.568487, 0.667482, 0.697081, 0.689784, ]
# model_2 = [0.377561, 0.626751, 0.679734, 0.681014, ]
# model_3 = [0.533394, 0.661159, 0.689386, 0.699001, ]
# model_4 = [0.542038, 0.667948, 0.690224, 0.690198, ]
# model_5 = [0.51286, 0.650669, 0.683958, 0.688107, ]
# model_6 = [0.536269, 0.662333, 0.680904, 0.695378]
# model_7 = [0.432143, 0.596636, 0.66444, 0.679245, ]
# model_8 = [0.525424, 0.656769, 0.709514, 0.691449, ]
# model_9 = [0.372849, 0.565513, 0.657824, 0.68081, ]
# model_10 = [0.291684, 0.4569, 0.598364, , ,]
# model_11 = [0.567256, 0.676026, 0.691957, 0.699171, ]
# model_12 = [0.473616, 0.64432, 0.679625, 0.686073, ]
# model_13 = [0.546433, 0.673645, 0.692284, 0.693066, ]
# model_14 = [0.545799, 0.545719, 0.687902, 0.68149, ]
# model_15 = [0.55149, 0.672659, 0.699372, 0.70337, ]

# %%
plt.plot(x_values, esb_list, color = "dodgerblue", alpha = 0.5)
plt.scatter(x_values, esb_list, c = 'dodgerblue')
plt.plot(x_values, sur_list, color = "#2ca02c", alpha = 0.5)
plt.scatter(x_values, sur_list, c = '#2ca02c')
plt.plot(x_values, maj_list, color = "#9467bd", alpha = 0.5)
plt.scatter(x_values, maj_list, c = '#9467bd')
# plt.plot(x_values, single_list, color = "#ff7f0e")

plt.legend(['Soft Voting', 'Survival', 'Majority'])

plt.xlabel('Epoch')
plt.ylabel('TQE')
# plt.title('PlusMinus Accuracy')
# plt.savefig('compare TQE.png', dpi=300, bbox_inches='tight', pad_inches=0)
plt.show()

# %% [markdown]
# ### 각 모델 정확도 표
