# %% [markdown]
# # **Attention Ensemble  - Survival(SoftVoting)**
# ---

# %% [markdown]
# ### **Import Libraries**

# %%
import tensorflow as tf
from keras.models import Model
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from sklearn.model_selection import train_test_split 

import unicodedata
import re
import numpy as np
import os
import io
import time
import random
import openpyxl

# %% [markdown]
# ### **데이터 로드**

# %%
path_to_file_esb = '/Users/ahjeong_park/Study/Attention-Ensemble-Translation/spa-eng/spa_for_esb.txt'

# %% [markdown]
# ### **데이터(문장) 전처리**

# %%
# 유니코드 파일을 아스키 코드 파일로 변환합니다.
def unicode_to_ascii(s):
  return ''.join(c for c in unicodedata.normalize('NFD', s)
      if unicodedata.category(c) != 'Mn')


def preprocess_sentence(w):
  w = unicode_to_ascii(w.lower().strip())

  # 단어와 단어 뒤에 오는 구두점(.)사이에 공백을 생성합니다.
  # 예시: "he is a boy." => "he is a boy ."
  # 참고:- https://stackoverflow.com/questions/3645931/python-padding-punctuation-with-white-spaces-keeping-punctuation
  w = re.sub(r"([?.!,¿])", r" \1 ", w)
  w = re.sub(r'[" "]+', " ", w)

  # (a-z, A-Z, ".", "?", "!", ",")을 제외한 모든 것을 공백으로 대체합니다.
  w = re.sub(r"[^a-zA-Z?.!,¿]+", " ", w)

  w = w.strip()

  # 모델이 예측을 시작하거나 중단할 때를 알게 하기 위해서
  # 문장에 start와 end 토큰을 추가합니다.
  w = '<start> ' + w + ' <end>'
  return w

# %% [markdown]
# ### **Dataset 생성**
# 1. 문장에 있는 억양을 제거합니다.
# 2. 불필요한 문자를 제거하여 문장을 정리합니다.
# 3. 다음과 같은 형식으로 문장의 쌍을 반환합니다: [영어, 스페인어]

# %%
def create_dataset(path, num_examples):
  lines = io.open(path, encoding='UTF-8').read().strip().split('\n')

  word_pairs = [[preprocess_sentence(w) for w in l.split('\t')]  for l in lines[:num_examples]]

  return zip(*word_pairs)

# %% [markdown]
# ### **Language 가 들어오면 공백 단위로 토큰화**
# - fit_on_texts(): 문자 데이터를 입력받아서 리스트의 형태로 변환
# - texts_to_sequences: 텍스트 안의 단어들을 숫자 시퀀스로 출력
# - pad_sequcences(tensor, padding='post') : 서로 다른 개수의 단어로 이루어진 문장을 같은 길이로 만들어주기 위해 패딩을 사용
#   - padding = 'post' : [[ 0  0  0  5  3  2  4], [ 0  0  0  5  3  2  7],...,]
#   - padding = 'pre' : 뒤 부터 패딩이 채워짐
#   - 가장 긴 sequence 의 길이 만큼

# %%
def tokenize(lang):
  lang_tokenizer = tf.keras.preprocessing.text.Tokenizer(
      filters='')
  lang_tokenizer.fit_on_texts(lang)

  tensor = lang_tokenizer.texts_to_sequences(lang)

  tensor = tf.keras.preprocessing.sequence.pad_sequences(tensor,
                                                         padding='post')

  return tensor, lang_tokenizer

# %% [markdown]
# ### **전처리된 타겟 문장과 입력 문장 쌍을 생성**
# - input_tensor : input 문장의 패딩 처리된 숫자 시퀀스
# - inp_lang_tokenizer : input 문장을 공백 단위로 토큰화, 문자 -> 리스트 변환
# - target_tensor, targ_lang_tokenizer : 위와 비슷

# %%
def load_dataset(path, num_examples=None):
  
  targ_lang, inp_lang = create_dataset(path, num_examples)

  input_tensor, inp_lang_tokenizer = tokenize(inp_lang)
  target_tensor, targ_lang_tokenizer = tokenize(targ_lang)

  return input_tensor, target_tensor, inp_lang_tokenizer, targ_lang_tokenizer

# %% [markdown]
# ### **언어 데이터셋 크기 제한**
# - 언어 데이터셋을 아래의 크기로 제한하여 훈련과 검증을 수행
# - inp_lang, targ_lang : 인풋,타겟 문장의 문자 -> 리스트 변환 결과
# - max_length_targ, max_length_inp : 인풋, 타겟 문장의 '패딩된' 숫자 시퀀스 길이 -> 타겟 텐서와 입력 텐서의 최대 길이

# %%
# num_examples = 30000
num_examples = 60000
input_tensor, target_tensor, inp_lang, targ_lang = load_dataset(path_to_file_esb, num_examples)

max_length_targ, max_length_inp = target_tensor.shape[1], input_tensor.shape[1]

# %% [markdown]
# ### **데이터셋 (테스트 & 검증) 분리**

# %%
# 훈련 집합과 검증 집합을 80대 20으로 분리합니다.
input_tensor_train, input_tensor_val, target_tensor_train, target_tensor_val = train_test_split(input_tensor, target_tensor, test_size=0.2)

# 훈련 집합과 검증 집합의 데이터 크기를 출력합니다.
print(len(input_tensor_train), len(target_tensor_train), len(input_tensor_val), len(target_tensor_val))
# Out:
# 48000 48000 12000 12000

# %% [markdown]
# ### 인덱스 -> 해당 word 로
#
# ```
# Input Language; index to word mapping
# 1 ----> <start>
# 93 ----> tomas
# 27 ----> le
# 1063 ----> escribio
# 7 ----> a
# 120 ----> maria
# 3 ----> .
# 2 ----> <end>
# ```
#
#
# ```
# Target Language; index to word mapping
# 1 ----> <start>
# 8 ----> tom
# 695 ----> wrote
# 6 ----> to
# 31 ----> mary
# 3 ----> .
# 2 ----> <end>
# ```

# %%
def convert(lang, tensor):
  for t in tensor:
    if t!=0:
      print ("%d ----> %s" % (t, lang.index_word[t]))

# %% [markdown]
# ### **Buffer, Batch, epoch, embedding dimension, units 설정**
# - Tokenizer 의 word_index 속성 : 속성은 단어와 숫자의 키-값 쌍을 포함하는 딕셔너리를 반환
# - 따라서 vocab_inp_size, vocab_inp_size : 인풋, 타겟의 단어-숫자 딕셔너리 최대 길이 + 1 (?)
# - dataset.batch(BATCH_SIZE, drop_remainder = True) : 배치사이즈 만큼 분할 후 남은 데이터를 drop 할 것인지 여부
# - shuffle : 데이터셋 적절히 섞어준다.

# %%
BUFFER_SIZE = len(input_tensor_train)
BATCH_SIZE = 64
steps_per_epoch = len(input_tensor_train)//BATCH_SIZE
embedding_dim = 256
units = 1024
vocab_inp_size = len(inp_lang.word_index)+1
vocab_tar_size = len(targ_lang.word_index)+1

# 훈련 집합에서만 shuffle, batch
dataset = tf.data.Dataset.from_tensor_slices((input_tensor_train, target_tensor_train)).shuffle(BUFFER_SIZE)
dataset = dataset.batch(BATCH_SIZE, drop_remainder=True)

# %%
example_input_batch, example_target_batch = next(iter(dataset))
example_input_batch.shape, example_target_batch.shape
# Out:
# (TensorShape([64, 53]), TensorShape([64, 51]))

# %% [markdown]
# ### **Encoder**
#
#
# 1.   초기화 : vocab_size(단어의 크기), embedding_dim(임베딩 차원 수), enc_units(인코더의 히든 사이즈), batch_sz(배치 사이즈)
#   - embedding_dim : 단어 -> 임베딩 벡터로 하기 위한 차원 수
# 2.  call : gru 에 들어가 output, state 출력
# 3.  initialize_hidden_state : 맨 처음 gru에 들어가기 위한 더미 입력 값

# %%
class Encoder(tf.keras.Model):
  def __init__(self, vocab_size, embedding_dim, enc_units, batch_sz):
    super(Encoder, self).__init__()
    self.batch_sz = batch_sz
    self.enc_units = enc_units
    self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
    self.gru = tf.keras.layers.GRU(self.enc_units,
                                   return_sequences=True,
                                   return_state=True,
                                   recurrent_initializer='glorot_uniform')

  def call(self, x, hidden):
    x = self.embedding(x)
    output, state = self.gru(x, initial_state = hidden)
    return output, state

  def initialize_hidden_state(self):
    return tf.zeros((self.batch_sz, self.enc_units))

# %% [markdown]
# ### **Encoder 객체 생성**

# %%
# encoder = Encoder(vocab_inp_size, embedding_dim, units, BATCH_SIZE)

# %% [markdown]
# ### **Attention**

# %%
class BahdanauAttention(tf.keras.layers.Layer):
  def __init__(self, units):
    super(BahdanauAttention, self).__init__()
    self.W1 = tf.keras.layers.Dense(units)
    self.W2 = tf.keras.layers.Dense(units)
    self.V = tf.keras.layers.Dense(1)

  def call(self, query, values):
    # 쿼리 은닉 상태(query hidden state)는 (batch_size, hidden size)쌍으로 이루어져 있습니다.
    # query_with_time_axis은 (batch_size, 1, hidden size)쌍으로 이루어져 있습니다.
    # values는 (batch_size, max_len, hidden size)쌍으로 이루어져 있습니다.
    # 스코어(score)계산을 위해 덧셈을 수행하고자 시간 축을 확장하여 아래의 과정을 수행합니다.
    query_with_time_axis = tf.expand_dims(query, 1)

    # score는 (batch_size, max_length, 1)쌍으로 이루어져 있습니다.
    # score를 self.V에 적용하기 때문에 마지막 축에 1을 얻습니다.
    # self.V에 적용하기 전에 텐서는 (batch_size, max_length, units)쌍으로 이루어져 있습니다.
    score = self.V(tf.nn.tanh(
        self.W1(query_with_time_axis) + self.W2(values)))

    # attention_weights는 (batch_size, max_length, 1)쌍으로 이루어져 있습니다. 
    attention_weights = tf.nn.softmax(score, axis=1)

    # 덧셈이후 컨텍스트 벡터(context_vector)는 (batch_size, hidden_size)쌍으로 이루어져 있습니다.
    context_vector = attention_weights * values
    context_vector = tf.reduce_sum(context_vector, axis=1)

    return context_vector, attention_weights

# %% [markdown]
# ### **Decoder**
#
#
# 1.   초기화 : vocab_size(단어의 크기), embedding_dim(임베딩 차원 수), enc_units(인코더의 히든 사이즈), batch_sz(배치 사이즈)
# 2.   encoder 와의 차이점 : 마지막 fully_connected_layer(tf.keras.layers.Dense) 추가

# %%
class Decoder(tf.keras.Model):
  def __init__(self, vocab_size, embedding_dim, dec_units, batch_sz):
    super(Decoder, self).__init__()
    self.batch_sz = batch_sz
    self.dec_units = dec_units
    self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
    self.gru = tf.keras.layers.GRU(self.dec_units,
                                   return_sequences=True,
                                   return_state=True,
                                   recurrent_initializer='glorot_uniform')
    self.fc = tf.keras.layers.Dense(vocab_size)

    # 어텐션을 사용합니다.
    self.attention = BahdanauAttention(self.dec_units)

  def call(self, x, hidden, enc_output):
    # enc_output는 (batch_size, max_length, hidden_size)쌍으로 이루어져 있습니다.
    context_vector, attention_weights = self.attention(hidden, enc_output)

    # 임베딩층을 통과한 후 x는 (batch_size, 1, embedding_dim)쌍으로 이루어져 있습니다.
    x = self.embedding(x)

    # 컨텍스트 벡터와 임베딩 결과를 결합한 이후 x의 형태는 (batch_size, 1, embedding_dim + hidden_size)쌍으로 이루어져 있습니다.
    x = tf.concat([tf.expand_dims(context_vector, 1), x], axis=-1)

    # 위에서 결합된 벡터를 GRU에 전달합니다.
    output, state = self.gru(x)

    # output은 (batch_size * 1, hidden_size)쌍으로 이루어져 있습니다.
    output = tf.reshape(output, (-1, output.shape[2]))

    # output은 (batch_size, vocab)쌍으로 이루어져 있습니다.
    x = self.fc(output)

    # return x, state, attention_weights
    return x, state

# %% [markdown]
# ### **Decoder 객체 생성**

# %%
# decoder = Decoder(vocab_tar_size, embedding_dim, units, BATCH_SIZE)

# %% [markdown]
# ### **NMT Model 생성**

# %%
class NMT_Model():
  def __init__(self):
    super(NMT_Model, self).__init__()
    self.encoder = Encoder(vocab_inp_size, embedding_dim, units, BATCH_SIZE)
    self.decoder = Decoder(vocab_tar_size, embedding_dim, units, BATCH_SIZE)

# %% [markdown]
# ### **Ensemble Model 생성**

# %%
models = []
num_models = 5
for m in range(num_models):
  m = NMT_Model()
  models.append(m)

# %% [markdown]
# ### **Loss Function & Optimizer**

# %%
optimizer = tf.keras.optimizers.Adam()
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(
    from_logits=True, reduction='none')

def loss_function(real, pred):
  mask = tf.math.logical_not(tf.math.equal(real, 0))
  loss_ = loss_object(real, pred)

  mask = tf.cast(mask, dtype=loss_.dtype)
  loss_ *= mask

  return tf.reduce_mean(loss_)

# %% [markdown]
# ### **Chekcpoint**
# - 여기서 학습한 매개변수를 저장, optimizer/encoder/decoder

# %%
checkpoint_dir = '/Users/ahjeong_park/Study/Attention-Ensemble-Translation/training_checkpoints_esb'
checkpoint_dir_test = '/Users/ahjeong_park/Study/Attention-Ensemble-Translation/training_checkpoints_esb2'
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")
checkpoints = []

for m in range(num_models):
  checkpoint = tf.train.Checkpoint(optimizer=optimizer,
                                 encoder=models[m].encoder,
                                 decoder=models[m].decoder)
  checkpoints.append(checkpoint)

# %%
print(checkpoints)
# Out:
# [<tensorflow.python.training.tracking.util.Checkpoint object at 0x7fe1f5c13d30>, <tensorflow.python.training.tracking.util.Checkpoint object at 0x7fe057b44d30>, <tensorflow.python.training.tracking.util.Checkpoint object at 0x7fe10a1af518>, <tensorflow.python.training.tracking.util.Checkpoint object at 0x7fe10a1af5f8>, <tensorflow.python.training.tracking.util.Checkpoint object at 0x7fe10a1af470>]

# %% [markdown]
# ### **Train_step**

# %%
# @tf.function
def train_step(model, inp, targ, enc_hidden):
  loss = 0

  with tf.GradientTape() as tape:
    enc_output, enc_hidden = model.encoder(inp, enc_hidden)

    dec_hidden = enc_hidden

    dec_input = tf.expand_dims([targ_lang.word_index['<start>']] * BATCH_SIZE, 1)

    # 교사 강요(teacher forcing) - 다음 입력으로 타겟을 피딩(feeding)합니다.
    for t in range(1, targ.shape[1]):
      # enc_output를 디코더에 전달합니다.
      predictions, dec_hidden = model.decoder(dec_input, dec_hidden, enc_output)
      # print('predictions', predictions.shape)

      loss += loss_function(targ[:, t], predictions)

      # 교사 강요(teacher forcing)를 사용합니다. -> 훈련에서는 실제 값을 이용
      dec_input = tf.expand_dims(targ[:, t], 1)

  batch_loss = (loss / int(targ.shape[1]))
  variables = model.encoder.trainable_variables + model.decoder.trainable_variables
  gradients = tape.gradient(loss, variables)
  optimizer.apply_gradients(zip(gradients, variables))
  return batch_loss

# %% [markdown]
# ### **학습**
# - 학습 코드 X

# %% [markdown]
# ### **문장 번역(스페인 -> 영어)**
#
# *   tf.keras.preprocessing.sequence.pad_sequences([inputs], maxlen='', padding='post') : 일정한 길이(maxlen)로 맞춰준다. (패딩은 뒤에서)
# *
#
#   ```
#   inp_lang.word_index :  {'<start>': 1, '<end>': 2, '.': 3, 'tom': 4, '?': 5...}
#   ```
#
# * tf.expand_dims: 차원을 늘려준다.

# %%
def evaluate(sentence):


  sentence = preprocess_sentence(sentence)

  # 문장, input 딕셔너리 출력 
  print ('sentence:', sentence)

  no_word = 'no word'

  input_list = []
   
  for j in range(5):
    inp = []
    for i in sentence.split(' '):
        if i in inp_lang.word_index:
            inp.append(inp_lang.word_index[i])
        else:
            print('no words!')
            return no_word, sentence
    input_list.append(inp)
    

  for input in range(len(input_list)):
    input_list[input] = tf.keras.preprocessing.sequence.pad_sequences([input_list[input]],
                                                         maxlen=max_length_inp,
                                                         padding='post')
    input_list[input] = tf.convert_to_tensor(input_list[input])
    
  voting_result = ''
  
  hiddens = []
  for i in range(5):
    hiddens.append([tf.zeros((1, units))])

  # enc_out, dec_hidden, dec_input 리스트 생성
  enc_outs = []
  enc_hiddens = []
  dec_hiddens = [] 
  dec_inputs = []

  # Encoder 의 hidden 을 Decoder 의 hidden 으로 받는다.
  for i in range(5):
    eo, eh = models[i].encoder(input_list[i], hiddens[i])
    enc_outs.append(eo)
    enc_hiddens.append(eh)
    

  for i in range(5):
    dec_hiddens.append(enc_hiddens[i])


  # Decoder 의 시작인 '<start>' 
  for i in range(5):
    dec_inputs.append(tf.expand_dims([targ_lang.word_index['<start>']], 0))


  # Model Prediction List
  pred_list = []   # 모델 1~5 의 predictions 가 저장되어 있는 리스트
  pred_ids = []    # 모델 1~5의 predictions 에서 가장 큰 값을 가지는 인덱스가 저장되어 있는 리스트
  pred_num = 5     
  max_list = []    # 모델 1~5의 predictions 에서 가장 큰 값을 나타내는 리스트
  suvi_models = models.copy()

  # Target 의 최대 길이 만큼 출력
  for t in range(max_length_inp):
    if pred_num != 1:
        for pred in range(pred_num):
            predictions, dec_hidden = suvi_models[pred].decoder(dec_inputs[pred],
                                                             dec_hiddens[pred],
                                                             enc_outs[pred])
            pred_list.append(predictions)
            dec_hiddens[pred] = dec_hidden

            max_idx = tf.argmax(predictions[0]).numpy()
            pred_ids.append(max_idx)

            # 각 모델의 time step 에서 가장 큰 값 확인 (제일 작은 모델을 제외할 예정)
            # 각 모델의 예측에서 가장 큰 확률 값만 모아놓은 리스트
            max_list.append(predictions[0][max_idx])




        # 서바이벌 - 제일 나쁜 모델 탈락
        # 제일 낮은 확률을 가진 모델을 나타내는 인덱스 --> worst
        worst = max_list.index(min(max_list))

        # worst 모델을 목록에서 삭제
        del pred_list[worst]
        del suvi_models[worst]
        del dec_hiddens[worst]
        del enc_outs[worst]
#         print(worst, '번째 모델 탈락')


        # Soft Voting
        predictions_sum = 0
        for pred in pred_list:
            predictions_sum = tf.add(predictions_sum, pred[0])
        mean = tf.divide(predictions_sum, pred_num)
        voting_id = tf.argmax(mean).numpy()
#         voting_id = pred_ids[max_list.index(max(max_list))]

        pred_ids = []
        max_list = []
        pred_num -= 1

        voting_result += targ_lang.index_word[voting_id] + ' '

        if targ_lang.index_word[voting_id] == '<end>':
          return voting_result, sentence

        del dec_inputs[worst]
        # 예측된 ID를 모델에 다시 피드합니다. (voting_id)
        for i in range(pred_num):
            dec_inputs[i] = tf.expand_dims([voting_id], 0)
    else:

        predictions, dec_hiddens[0] = suvi_models[0].decoder(dec_inputs[0],
                                                             dec_hiddens[0],
                                                             enc_outs[0])
        predicted_id = tf.argmax(predictions[0]).numpy() 
        voting_result += targ_lang.index_word[predicted_id] + ' '
        
        if targ_lang.index_word[predicted_id] == '<end>':
          return voting_result, sentence
    
        # 예측된 ID를 모델에 다시 피드합니다.
        dec_inputs[0] = tf.expand_dims([predicted_id], 0)
        

  return voting_result, sentence

# %%
def translate(sentence):
    voting_result, sentence = evaluate(sentence)
    
    
    print('Survival Voting_result: ', voting_result)
    
    return voting_result

#     # 엑셀 파일 불러오기
#     wb = openpyxl.load_workbook('BLEU_Score.xlsx')

#     # 엑셀 파일의 시트 활성화
#     sheet1 = wb['HardVoting(2)']
#     sheet2 = wb['HardVoting(2)']
#     sheet3 = wb['HardVoting(2)']
#     sheet4 = wb['HardVoting(2)']
#     sheet5 = wb['HardVoting(2)']

#     sheet1.cell(row = start_row, column = ).value = result1
#     sheet2.cell(row = start_row, column = ).value = result2
#     sheet3.cell(row = start_row, column = ).value = result3
#     sheet4.cell(row = start_row, column = ).value = result4
#     sheet5.cell(row = start_row, column = ).value = result5
        

#     wb.save('BLEU_Score.xlsx')

# %% [markdown]
# ### **Checkpoint 복원**

# %%
ckp_dir_m1 = '/Users/ahjeong_park/Study/Attention-Ensemble-Translation/5 Models Checkpoints_60000/training_checkpoints_esb'
ckp_dir_m2 = '/Users/ahjeong_park/Study/Attention-Ensemble-Translation/5 Models Checkpoints_60000/training_checkpoints_esb 2'
ckp_dir_m3 = '/Users/ahjeong_park/Study/Attention-Ensemble-Translation/5 Models Checkpoints_60000/training_checkpoints_esb 3'
ckp_dir_m4 = '/Users/ahjeong_park/Study/Attention-Ensemble-Translation/5 Models Checkpoints_60000/training_checkpoints_esb 4'
ckp_dir_m5 = '/Users/ahjeong_park/Study/Attention-Ensemble-Translation/5 Models Checkpoints_60000/training_checkpoints_esb 5'

# %%
# checkpoint_dir내에 있는 최근 체크포인트(checkpoint)를 복원
checkpoints[0].restore(tf.train.latest_checkpoint(ckp_dir_m1))
checkpoints[1].restore(tf.train.latest_checkpoint(ckp_dir_m2))
checkpoints[2].restore(tf.train.latest_checkpoint(ckp_dir_m3))
checkpoints[3].restore(tf.train.latest_checkpoint(ckp_dir_m4))
checkpoints[4].restore(tf.train.latest_checkpoint(ckp_dir_m5))

### 이 코드로 했을 때 학습 바로 돌렸을 때와 같은 결과가 나왔음.

# %% [markdown]
# ### **번역 시작**

# %%
# test dataset 파일 불러오기
testdata = '/Users/ahjeong_park/Study/Attention-Ensemble-Translation/BLEU/test_data.txt'
start_row = 2

# 엑셀 파일 불러오기
wb = openpyxl.load_workbook('Survival_Translate.xlsx')

# 엑셀 파일의 시트 활성화
sheet1 = wb['Survival(Soft)']

f = open(testdata, 'r')
lines = f.readlines()

for sentence in lines:
    result = translate(sentence)
    
    sheet1.cell(row = start_row, column = 4).value = result

    start_row += 1
    
f.close()
wb.save('Survival_Translate.xlsx')
# Out:
# sentence: <start> te dijeron lo que paso , ¿ no ? <end>
# Survival Voting_result:  you were told told you , what time ? <end>
# sentence: <start> ellos no estaban alla . <end>
# Survival Voting_result:  they were not not there . <end>
# sentence: <start> no me gusta ninguno de los chicos . <end>
# Survival Voting_result:  i don don t like any boys . <end>
# sentence: <start> jamas trabaje con el . <end>
# Survival Voting_result:  i never never work with him . <end>
# sentence: <start> mi padre cultiva arroz . <end>
# Survival Voting_result:  my father father sometimes drinks . <end>
# sentence: <start> dime que hiciste en shounan . <end>
# Survival Voting_result:  tell me me you did . <end>
# sentence: <start> ¿ cuantas palabras deberias escribir ? <end>
# Survival Voting_result:  how many many many should you eat ? <end>
# sentence: <start> ¿ como te introdujiste en mi casa ? <end>
# Survival Voting_result:  how how did did you take you my house ? <end>
# sentence: <start> mi madre hornea pan todas las mananas . <end>
# Survival Voting_result:  my mother mother bakes every morning . <end>
# sentence: <start> yo he disfrutado el leer esta novela . <end>
# Survival Voting_result:  i take enjoyed enjoyed this novel . <end>
# sentence: <start> el estaba parado en la esquina . <end>
# Survival Voting_result:  he he stood stood up at the corner . <end>
# sentence: <start> el testigo no parecia estar nervioso cuando testifico en el juicio . <end>
# Survival Voting_result:  the man man didn t seem to marry her in the matter . <end>
# sentence: <start> ¿ donde esta el zoologico ? <end>
# Survival Voting_result:  where is the the zoo ? <end>
# sentence: <start> el nombre de mi hijo es tom . <end>
# Survival Voting_result:  my name name is tom . <end>
# sentence: <start> tenemos cosas mas grandes de que preocuparnos . <end>
# Survival Voting_result:  we have have have bigger than to worry . <end>
# sentence: <start> juntemonos pasado manana . <end>
# Survival Voting_result:  let s go get together tomorrow . <end>
# sentence: <start> ¿ que estas escribiendo ? <end>
# Survival Voting_result:  what are you you ? <end>
# sentence: <start> ¿ este es tu vino ? <end>
# Survival Voting_result:  is this this this ? <end>
# sentence: <start> era casi imposible circular por esa calle . <end>
# no words!
# Survival Voting_result:  no word
# sentence: <start> pense que tom querria ayudarme . <end>
# Survival Voting_result:  i thought tom would want to help me . <end>
# sentence: <start> ¿ que le quieres regalar a tom ? <end>
# Survival Voting_result:  what do you do you want to tom ? <end>
# sentence: <start> no quiero permitir que eso suceda . <end>
# Survival Voting_result:  i don don t want to allow that happen . <end>
# sentence: <start> no queda rollo de papel . <end>
# Survival Voting_result:  there is no no paper left . <end>
# sentence: <start> ¿ vas a venir a visitarme ? <end>
# Survival Voting_result:  are you you going to come to me ? <end>
# sentence: <start> asumo que estas aqui para preguntarme por tom . <end>
# Survival Voting_result:  i assume you you re here to ask me for me . <end>
# sentence: <start> tom le aprecio a mary su bondad . <end>
# Survival Voting_result:  tom appreciated mary mary s kindness . <end>
# sentence: <start> ¿ donde esta la otra ? <end>
# Survival Voting_result:  where is the the other one ? <end>
# sentence: <start> los pobres no siempre son infelices . <end>
# Survival Voting_result:  the poor poor children are not getting expensive . <end>
# sentence: <start> la perseverancia , como usted sabe , es la llave al exito . <end>
# Survival Voting_result:  he is often , is the key . <end>
# sentence: <start> tom aparece a veces en la television . <end>
# Survival Voting_result:  tom sometimes sometimes goes to tv . <end>
# sentence: <start> me gusta el perro . <end>
# Survival Voting_result:  i like like like the dog . <end>
# sentence: <start> es algo que tengo que hacer . <end>
# Survival Voting_result:  it is something something i have to do . <end>
# sentence: <start> tom no era muy bueno para leer entre lineas . <end>
# Survival Voting_result:  tom wasn wasn wasn t very good at studying in china . <end>
# sentence: <start> ¿ podrias venir aca ? <end>
# Survival Voting_result:  could you you come over here ? <end>
# sentence: <start> esa racha de suerte no durara para siempre . <end>
# Survival Voting_result:  this lucky lucky lucky that we weren t going to rain . <end>
# sentence: <start> ¿ caminaste todo el camino hasta aca ? <end>
# no words!
# Survival Voting_result:  no word
# sentence: <start> pense que tom habia dejado a mary hace un mes . <end>
# Survival Voting_result:  i thought tom had a big month . <end>
# sentence: <start> dibuja una linea en el folio . <end>
# no words!
# Survival Voting_result:  no word
# sentence: <start> la fogata sigue encendida . <end>
# Survival Voting_result:  the the border education is on . <end>
# sentence: <start> es cruel burlarse de un ciego . <end>
# Survival Voting_result:  it is is cruel of honor . <end>
# sentence: <start> que hermoso regalo ! <end>
# Survival Voting_result:  what a a beautiful present ! <end>
# sentence: <start> actualmente , tom no tiene empleo . <end>
# Survival Voting_result:  tom is , tom doesn t have a job . <end>
# sentence: <start> la ciudad estaba envuelta en niebla . <end>
# Survival Voting_result:  the city city was alarmed in fog . <end>
# sentence: <start> ¿ sabes como usar esto ? <end>
# Survival Voting_result:  do you you you use how to use this ? <end>
# sentence: <start> tom ceno hace mas o menos una hora . <end>
# Survival Voting_result:  tom ate dinner more than an hour . <end>
# sentence: <start> ¿ podrias darme tu nombre y tu numero de telefono ? <end>
# Survival Voting_result:  could you you you name your name and your telephone number ? <end>
# sentence: <start> los documentos secretos fueron triturados . <end>
# no words!
# Survival Voting_result:  no word
# sentence: <start> tom esta en una racha de suerte . <end>
# Survival Voting_result:  tom is in in a winning streak . <end>
# sentence: <start> el enemigo mas terrible es un amigo pasado . <end>
# Survival Voting_result:  the enemy enemy is a friend s a . <end>
# sentence: <start> tom es un conductor muy precavido . <end>
# Survival Voting_result:  tom is a a few pain . <end>
# sentence: <start> vendere mi casa . <end>
# Survival Voting_result:  i will keep my house . <end>
# sentence: <start> tom esta un poco resfriado . <end>
# Survival Voting_result:  tom is a a bad cold . <end>
# sentence: <start> arrodillaos . <end>
# no words!
# Survival Voting_result:  no word
# sentence: <start> que tonteria ! <end>
# Survival Voting_result:  how foolish foolish of you ! <end>
# sentence: <start> este cuchillo esta tan desafilado que no puede cortar . <end>
# no words!
# Survival Voting_result:  no word
# sentence: <start> sera mejor que empieces ya . <end>
# Survival Voting_result:  you will better be done . <end>
# sentence: <start> ¿ a que tom es popular ? <end>
# Survival Voting_result:  what is tom is interested ? <end>
# sentence: <start> no se por que el renuncio a la compania . <end>
# Survival Voting_result:  i don don t know why he quit the company . <end>
# sentence: <start> por favor dejame ir . <end>
# Survival Voting_result:  please let go go . <end>
# sentence: <start> la ceremonia inaugural se realizo ayer . <end>
# no words!
# Survival Voting_result:  no word
# sentence: <start> por eso quiero hablar con tom . <end>
# Survival Voting_result:  that for that i want to speak with tom . <end>
# sentence: <start> sin importar cuanto coma , ella no sube de peso . <end>
# Survival Voting_result:  no matter how how much i should not to lose weight . <end>
# sentence: <start> es un milagro que tom siga vivo . <end>
# Survival Voting_result:  it is a a miracle that tom is still alive . <end>
# sentence: <start> conduce con cuidado . <end>
# Survival Voting_result:  drive carefully carefully . <end>
# sentence: <start> en verano , la gente va a la playa . <end>
# Survival Voting_result:  in the summer , people go to the beach . <end>
# sentence: <start> por favor , saque la lengua . <end>
# Survival Voting_result:  please please give give me the tongue . <end>
# sentence: <start> tom tiene una calva . <end>
# no words!
# Survival Voting_result:  no word
# sentence: <start> me gustaria que le echaras un vistazo . <end>
# Survival Voting_result:  i would d like you to kick you a look . <end>
# sentence: <start> durante la guerra , la gente paso muchos apuros . <end>
# Survival Voting_result:  for the war war , many people died . <end>
# sentence: <start> ¿ con quien desea hablar ? <end>
# Survival Voting_result:  who do do you want to speak to ? <end>
# sentence: <start> ¿ son americanos ? <end>
# Survival Voting_result:  are they they american ? <end>
# sentence: <start> tengo un hijo y una hija . mi hijo esta en nueva york y mi hija en londres . <end>
# Survival Voting_result:  i have have a son and a daughter . <end>
# sentence: <start> llevo marcapasos . <end>
# no words!
# Survival Voting_result:  no word
# sentence: <start> este trabajo es lo suficientemente simple para que lo haga un nino . <end>
# Survival Voting_result:  this work is is difficult for a little girl is to make a child . <end>
# sentence: <start> nunca he ido al extranjero . <end>
# Survival Voting_result:  i have never never been to the weather . <end>
# sentence: <start> comamos mientras este caliente . <end>
# Survival Voting_result:  let s eat eat this hot . <end>
# sentence: <start> odio estar soltero . <end>
# Survival Voting_result:  i hate hate hate . <end>
# sentence: <start> no os preocupeis por mi . <end>
# Survival Voting_result:  don t t t give you for me . <end>
# sentence: <start> ella me evita . <end>
# Survival Voting_result:  she she s fascinated me . <end>
# sentence: <start> me desperte tres veces durante la noche . <end>
# Survival Voting_result:  i woke myself up during the evening during the night . <end>
# sentence: <start> el nino cogio un pez grande . <end>
# Survival Voting_result:  the child child child to a large fish . <end>
# sentence: <start> tom perdio sus gafas . <end>
# Survival Voting_result:  tom lost his his glasses . <end>
# sentence: <start> la puerta se abrio y un hombre entro . <end>
# Survival Voting_result:  the door door door and a man walked in . <end>
# sentence: <start> me gusta la pizza fria . <end>
# Survival Voting_result:  i like like really cold . <end>
# sentence: <start> ¿ puedo llamar a londres desde aqui ? <end>
# Survival Voting_result:  may i i i park from london ? <end>
# sentence: <start> digalo en ingles . <end>
# Survival Voting_result:  say it in in english . <end>
# sentence: <start> por esa razon perdio su trabajo . <end>
# Survival Voting_result:  that that s s lost his job . <end>
# sentence: <start> creo que eres tonto . <end>
# Survival Voting_result:  i think you you re stupid . <end>
# sentence: <start> extrano a mis amigos . <end>
# Survival Voting_result:  i miss my my friends . <end>
# sentence: <start> el me enseno a usar esta camara . <end>
# Survival Voting_result:  he he taught taught me to use this camera . <end>
# sentence: <start> esta casa es demasiado chica para vivir . <end>
# Survival Voting_result:  this house is is too small to live . <end>
# sentence: <start> tom me dijo eso antes . <end>
# Survival Voting_result:  tom told told me that before . <end>
# sentence: <start> el salmon va rio arriba y pone sus huevos en la arena . <end>
# Survival Voting_result:  the he is is five gallons and settled every meal . <end>
# sentence: <start> bebe mucha agua . <end>
# Survival Voting_result:  drink a great water . <end>
# sentence: <start> no seas ridiculo ! <end>
# Survival Voting_result:  don t t be ! <end>
# sentence: <start> estoy sin blanca . <end>
# Survival Voting_result:  i am am out of white . <end>
# sentence: <start> no nos importa lo que el haga . <end>
# Survival Voting_result:  we don don t care what he does . <end>
# sentence: <start> ¿ es hoy viernes ? <end>
# Survival Voting_result:  is today today today ? <end>
# sentence: <start> dije que podia ir . <end>
# Survival Voting_result:  i said i said to go . <end>
# sentence: <start> ¿ a quien se lo diste ? <end>
# Survival Voting_result:  who did you did it take ? <end>
# sentence: <start> nunca se ha hecho antes . <end>
# Survival Voting_result:  you never ve never done before . <end>
# sentence: <start> ¿ cuantos ordenadores habeis tenido hasta ahora ? <end>
# Survival Voting_result:  how many do do you have to the time now ? <end>
# sentence: <start> tom dijo que estaria aqui pero no lo encuentro . <end>
# Survival Voting_result:  tom said he would be here , not know . <end>
# sentence: <start> me han hecho esperar mucho . <end>
# Survival Voting_result:  you ve ve got married to me very excited . <end>
# sentence: <start> todavia sueno con eso . <end>
# Survival Voting_result:  it still still still compared with it . <end>
# sentence: <start> tom ya esta en boston . <end>
# Survival Voting_result:  tom is is already in boston . <end>
# sentence: <start> el hombre se prendio a si mismo en llamas . <end>
# Survival Voting_result:  the man man man in his absence . <end>
# sentence: <start> estoy un poco loca . <end>
# Survival Voting_result:  i am a a crazy . <end>
# sentence: <start> estoy segura de que lo lograreis . <end>
# no words!
# Survival Voting_result:  no word
# sentence: <start> tom no queria trabajar horas extra en noche buena . <end>
# Survival Voting_result:  tom didn didn t want to work when i arrived at night . <end>
# sentence: <start> el levanto los ojos al cielo . <end>
# Survival Voting_result:  he he raised raised the sky . <end>
# sentence: <start> puedes usar mi bicicleta . <end>
# Survival Voting_result:  you can can use my bicycle . <end>
# sentence: <start> tom no puede nadar tan rapido como mary . <end>
# Survival Voting_result:  tom can can can swim as fast as mary . <end>
# sentence: <start> yo no entiendo el arte moderno . <end>
# Survival Voting_result:  i don don t understand modern art . <end>
# sentence: <start> se unas cuantas cosas . <end>
# Survival Voting_result:  i have a a lot of little things . <end>
# sentence: <start> ¿ alguien puede ayudarme ? <end>
# Survival Voting_result:  can anyone anyone help me ? <end>
# sentence: <start> ¿ tienes una familia grande ? <end>
# Survival Voting_result:  do you have you a big family ? <end>
# sentence: <start> tom empezo a comer . <end>
# Survival Voting_result:  tom started started to eat . <end>
# sentence: <start> son felices . <end>
# Survival Voting_result:  they re re happy . <end>
# sentence: <start> hay un mapa en la pared . <end>
# Survival Voting_result:  there is a a map on the wall . <end>
# sentence: <start> tom no mantuvo su promesa . <end>
# Survival Voting_result:  tom didn did not keep his promise . <end>
# sentence: <start> nuestra memoria empeora mientras mas viejos nos hacemos . <end>
# Survival Voting_result:  our our older memory as we become our time . <end>
# sentence: <start> el tenia tres hijos . <end>
# Survival Voting_result:  he had had had three children . <end>
# sentence: <start> ¿ has pintado esta casa alguna vez ? <end>
# Survival Voting_result:  have you the the house the house ? <end>
# sentence: <start> ¿ ya comiste ? <end>
# Survival Voting_result:  have you you eaten ? <end>
# sentence: <start> todo eso es culpa vuestra . <end>
# Survival Voting_result:  that s all all your fault . <end>
# sentence: <start> ¿ lo pillas ? <end>
# Survival Voting_result:  will i i i m it on me ? <end>
# sentence: <start> dijeron que los costos de almacenamiento eran demasiado altos . <end>
# no words!
# Survival Voting_result:  no word
# sentence: <start> algo terrible paso . <end>
# Survival Voting_result:  something terrible happened happened . <end>
# sentence: <start> me gustas como amigo . <end>
# Survival Voting_result:  i like like like the way . <end>
# sentence: <start> voy a espana la semana que viene . <end>
# Survival Voting_result:  i am i go out the next week . <end>
# sentence: <start> mi cantante favorita es kylie minogue . <end>
# no words!
# Survival Voting_result:  no word
# sentence: <start> no puedo beber alcohol . <end>
# Survival Voting_result:  i can can t hide happiness . <end>
# sentence: <start> pense que teniamos un trato . <end>
# Survival Voting_result:  i thought i had a deal . <end>
# sentence: <start> damelas ! <end>
# no words!
# Survival Voting_result:  no word
# sentence: <start> que no se te olvide escribirnos . <end>
# no words!
# Survival Voting_result:  no word
# sentence: <start> no puede refrenar sus deseos . <end>
# no words!
# Survival Voting_result:  no word
# sentence: <start> yo corri una milla . <end>
# Survival Voting_result:  i i was was a reward . <end>
# sentence: <start> eres un fraude . <end>
# Survival Voting_result:  you are a a gossip . <end>
# sentence: <start> no creo que tom y mary sean hermanos . <end>
# Survival Voting_result:  i don don t think tom and mary are brothers . <end>
# sentence: <start> ¿ conoces a un buen dentista ? <end>
# Survival Voting_result:  do you you you a good doctor ? <end>
# sentence: <start> hice un trato con tom . <end>
# Survival Voting_result:  i made made a deal with tom . <end>
# sentence: <start> tiene el nombre de tom en el . <end>
# Survival Voting_result:  tom tom s s on in . <end>
# sentence: <start> yo no tengo ganas de hablar . <end>
# Survival Voting_result:  i don don t feel like talking . <end>
# sentence: <start> estoy cansado de todo este fastidio . <end>
# Survival Voting_result:  i am tired tired of all over this headache . <end>
# sentence: <start> tus manos estan frias . <end>
# Survival Voting_result:  your hands are are right . <end>
# sentence: <start> prosigamos . <end>
# Survival Voting_result:  let s go go . <end>
# sentence: <start> no fueron capaces de descubrir ningun secreto . <end>
# Survival Voting_result:  they no no not able to settle any secret . <end>
# sentence: <start> tomas es muy manoso . <end>
# no words!
# Survival Voting_result:  no word
# sentence: <start> no es de buena educacion hablar con la boca llena . <end>
# Survival Voting_result:  it is isn isn t good thing to speak with your mouth full . <end>
# sentence: <start> yo me siento adormitado . <end>
# no words!
# Survival Voting_result:  no word
# sentence: <start> creo que mirar television es una perdida de tiempo . <end>
# Survival Voting_result:  i think i think i ll watch television in a time . <end>
# sentence: <start> la reina elizabeth i fallecio en . <end>
# no words!
# Survival Voting_result:  no word
# sentence: <start> el ha escrito muchas historias . <end>
# Survival Voting_result:  he wrote has a lot of stories . <end>
# sentence: <start> de todos los libros publicados ultimamente , solo algunos merecen ser leidos . <end>
# no words!
# Survival Voting_result:  no word
# sentence: <start> necesito regresar . <end>
# Survival Voting_result:  i need need to go back . <end>
# sentence: <start> probate este pullover . <end>
# no words!
# Survival Voting_result:  no word
# sentence: <start> tom actua como si ni conociera a maria . <end>
# Survival Voting_result:  tom tom is is not to mary . <end>
# sentence: <start> es mi ultima oferta . <end>
# Survival Voting_result:  it s my my offer . <end>
# sentence: <start> no me voy a casar nunca . <end>
# Survival Voting_result:  i don t t going to get married . <end>
# sentence: <start> no necesitas ir tan apurado . <end>
# Survival Voting_result:  you don don t need to go as a guitarist . <end>
# sentence: <start> para de decir eso ! <end>
# Survival Voting_result:  stop to say that ! <end>
# sentence: <start> los pilotos se comunican con el aeropuerto por radio . <end>
# Survival Voting_result:  the pilots pilots are jammed with the airport . <end>
# sentence: <start> la chica de la que te hable vive en kioto . <end>
# Survival Voting_result:  the girl girl i told you about lives in kyoto . <end>
# sentence: <start> lo que necesitamos ahora es un descanso . <end>
# Survival Voting_result:  what we we need is a rest . <end>
# sentence: <start> se breve . <end>
# Survival Voting_result:  be brief . . <end>
# sentence: <start> no conozco a ninguna de las dos hermanas . <end>
# Survival Voting_result:  i don don t know either girl sisters . <end>
# sentence: <start> nadie me escucho . <end>
# Survival Voting_result:  no one listen listen . <end>
# sentence: <start> esos son nuestros autos . <end>
# Survival Voting_result:  those are are are . <end>
# sentence: <start> ella prometio revisar inmediatamente el asunto . <end>
# Survival Voting_result:  she she promised will consider him while . <end>
# sentence: <start> ¿ habia alguien mas en el bar ? <end>
# Survival Voting_result:  was there anybody there in the bar ? <end>
# sentence: <start> ayer fui a ver el partido de beisbol . <end>
# Survival Voting_result:  i went yesterday went to study yesterday . <end>
# sentence: <start> se tan poco como tu . <end>
# Survival Voting_result:  i know know as you do . <end>
# sentence: <start> mi papa esta en el bano afeitandose . <end>
# no words!
# Survival Voting_result:  no word
# sentence: <start> han pasado dos semanas y no la he visto . <end>
# Survival Voting_result:  it has have two weeks and i haven t seen this . <end>
# sentence: <start> guarde lo mejor para el final . <end>
# Survival Voting_result:  keep the the better start . <end>
# sentence: <start> pusimos los regalos de navidad bajo el arbol . <end>
# Survival Voting_result:  we put the the christmas tree under the tree . <end>
# sentence: <start> no profundices demasiado en esta lectura . <end>
# no words!
# Survival Voting_result:  no word
# sentence: <start> tom no ha freido el pescado aun . <end>
# no words!
# Survival Voting_result:  no word
# sentence: <start> digame la verdad . <end>
# Survival Voting_result:  tell me the the question . <end>
# sentence: <start> tomese esta medicina antes de cada comida . <end>
# Survival Voting_result:  take as this this button to eat dinner . <end>
# sentence: <start> mi hermano menor nada todos los dias en verano . <end>
# Survival Voting_result:  my little brother brother every day . <end>
# sentence: <start> ¿ por que ella es tan popular ? <end>
# Survival Voting_result:  why is she she popular ? <end>
# sentence: <start> dame un pedazo de papel para escribir , por favor . <end>
# Survival Voting_result:  please give give me a sheet of view that please . <end>
# sentence: <start> para hawking , escribir este libro no fue facil . <end>
# no words!
# Survival Voting_result:  no word
# sentence: <start> no sabia que supieras conducir . <end>
# Survival Voting_result:  i didn didn t know you d drive . <end>
# sentence: <start> casi todas las chicas son amables . <end>
# Survival Voting_result:  almost all all all girls are very dumb . <end>
# sentence: <start> llevare dos completos con mostaza y ketchup . <end>
# no words!
# Survival Voting_result:  no word
# sentence: <start> no creo que tom vaya a regresar . <end>
# Survival Voting_result:  i don don t think tom will come back . <end>
# sentence: <start> tom , ¿ que quieres de cenar ? <end>
# Survival Voting_result:  tom , what do you want to have dinner ? <end>
# sentence: <start> alrededor del ano a . c . , su gente se volvio contra roma . <end>
# Survival Voting_result:  about the next year . it is getting in it in advance . <end>
# sentence: <start> kenia solia ser una colonia inglesa . <end>
# Survival Voting_result:  it used used to be a japanese english . <end>
# sentence: <start> ¿ que tal estuvo la fiesta de tom ? <end>
# Survival Voting_result:  how was was tom s party ? <end>
# sentence: <start> tom dijo que entiende como te sientes . <end>
# Survival Voting_result:  tom said he he thinks he feel . <end>
# sentence: <start> viven en la tercera avenida . <end>
# Survival Voting_result:  they live live in the stairs quickly . <end>
# sentence: <start> me sorprendio lo mucho que se parecia a su padre . <end>
# Survival Voting_result:  i was surprised surprised at his strong resemblance to his father . <end>
# sentence: <start> tom tendra que esperar . <end>
# Survival Voting_result:  tom will have will wait . <end>
# sentence: <start> tom fue incapaz de disimular su sorpresa . <end>
# no words!
# Survival Voting_result:  no word
# sentence: <start> necesito a alguien con quien hablar . <end>
# Survival Voting_result:  i need need to someone to talk to . <end>
# sentence: <start> estaba pensando en otra cosa . <end>
# Survival Voting_result:  i was just just like something else . <end>
# sentence: <start> tom finalmente se calmo . <end>
# Survival Voting_result:  tom finally finally finally himself . <end>
# sentence: <start> necesitas que hablemos de tu a tu . <end>
# Survival Voting_result:  you need need to talk about your own . <end>
# sentence: <start> este es un buen sushi . <end>
# Survival Voting_result:  this is is a good deal . <end>
# sentence: <start> no tengo prisa . <end>
# Survival Voting_result:  i don t have a hurry . <end>
# sentence: <start> segun la leyenda esta casa esta embrujada . <end>
# no words!
# Survival Voting_result:  no word
# sentence: <start> todo esta en tu cabeza . <end>
# Survival Voting_result:  everything s in in your head . <end>
# sentence: <start> esperare hasta las cuatro en punto . <end>
# Survival Voting_result:  i will wait wait for four o clock . <end>
# sentence: <start> ¿ por que esta tan caliente ? <end>
# Survival Voting_result:  why is is this hot ? <end>
# sentence: <start> ¿ cuando paso ? <end>
# Survival Voting_result:  when did did did it end ? <end>
# sentence: <start> es dificil creer lo que dices . <end>
# Survival Voting_result:  it is is difficult to say what you say . <end>
# sentence: <start> necesitas esto . <end>
# Survival Voting_result:  you need this this . <end>
# sentence: <start> has bebido tres tazas de cafe . <end>
# Survival Voting_result:  you have had had an apartment under coffee . <end>
# sentence: <start> ¿ somos amigas ? <end>
# Survival Voting_result:  are we we we all friends ? <end>
# sentence: <start> ire aunque llueva . <end>
# Survival Voting_result:  i will go go outside . <end>
# sentence: <start> tom esta jugando con sus juguetes . <end>
# Survival Voting_result:  tom is is playing with his toys . <end>
# sentence: <start> los celos en una relacion a menudo son provocados por la falta de confianza . <end>
# no words!
# Survival Voting_result:  no word
# sentence: <start> ¿ hace tanto frio en alemania como en canada ? <end>
# Survival Voting_result:  is it it it cold in canada ? <end>
# sentence: <start> su consejo no nos sirvio de nada . <end>
# Survival Voting_result:  his advice advice didn t help us at all . <end>
# sentence: <start> por favor toma tu tiempo . <end>
# Survival Voting_result:  please take take your time . <end>
# sentence: <start> el es muy viejo . <end>
# Survival Voting_result:  he is is is old . <end>
# sentence: <start> puede que sea posible para el , pero yo nunca pasare la prueba . <end>
# Survival Voting_result:  perhaps he may may be done for him , but i never will win . <end>
# sentence: <start> tom queria comprar un par nuevo de zapatillas de tenis . <end>
# Survival Voting_result:  tom wanted wanted to buy a new pair of toast . <end>
# sentence: <start> se le rompio la cuerda al reloj . <end>
# Survival Voting_result:  he broke broke his nose on the clock . <end>
# sentence: <start> dejaras de hacer eso si sabes lo que es bueno para ti . <end>
# Survival Voting_result:  you would would like that if you know what it s good to you . <end>
# sentence: <start> lo lamentaras ! <end>
# Survival Voting_result:  you will will ll regret it ! <end>
# sentence: <start> hay una necesidad urgente de dinero . <end>
# Survival Voting_result:  there is an an urgent need for money . <end>
# sentence: <start> tienen que ser estadounidenses . <end>
# Survival Voting_result:  they must must ve always americans . <end>
# sentence: <start> no tuvimos muchas visitas este verano . <end>
# Survival Voting_result:  we didn we had no railroads a lot of coffee . <end>
# sentence: <start> todos los camaradas dormian . <end>
# no words!
# Survival Voting_result:  no word
# sentence: <start> tom tiene miedo al compromiso . <end>
# Survival Voting_result:  tom is is afraid of habit . <end>
# sentence: <start> eso no es de tu incumbencia . <end>
# Survival Voting_result:  that isn isn t your business . <end>
# sentence: <start> queremos ir de boston a chicago . <end>
# Survival Voting_result:  we want want to go to boston . <end>
# sentence: <start> ella se decidio por el abrigo rojo . <end>
# Survival Voting_result:  she she made made from red hat . <end>
# sentence: <start> creia que eras mayor . <end>
# Survival Voting_result:  i thought you thought of you were better . <end>
# sentence: <start> ¿ que ha ocurrido ? <end>
# Survival Voting_result:  what happened happened happened ? <end>
# sentence: <start> muestrame como tengo que hacerlo , por favor . <end>
# Survival Voting_result:  show me me me to do it . <end>
# sentence: <start> ¿ ahora puedo empezar a comer ? <end>
# Survival Voting_result:  can i i i eat dinner ? <end>
# sentence: <start> no tengo palabras . <end>
# Survival Voting_result:  i don don t have a word . <end>
# sentence: <start> vamos a intentarlo . <end>
# Survival Voting_result:  let s go a try . <end>
# sentence: <start> ¿ y de ahi , que hubo ? <end>
# Survival Voting_result:  what about in in , what were there ? <end>
# sentence: <start> hace frio hoy . <end>
# Survival Voting_result:  it is cold cold today . <end>
# sentence: <start> tengo una idea diferente . <end>
# Survival Voting_result:  i have have a brilliant idea . <end>
# sentence: <start> ¿ puedo ofrecerle algo de beber ? <end>
# Survival Voting_result:  may i i i give you something to drink ? <end>
# sentence: <start> la pequena isla llego a la vista . <end>
# Survival Voting_result:  the small small small bang was on sight . <end>
# sentence: <start> el chico abrazo a su pecho al cachorro . <end>
# Survival Voting_result:  the boy boy sight of its tail . <end>
# sentence: <start> no sabia que estarian aqui . <end>
# Survival Voting_result:  i didn didn t know you d be here . <end>
# sentence: <start> tom es un buen cliente . <end>
# Survival Voting_result:  tom is a a good mood . <end>
# sentence: <start> ¿ estas enojada ? <end>
# Survival Voting_result:  are you you mad ? <end>
# sentence: <start> indicame adonde ir . <end>
# no words!
# Survival Voting_result:  no word
# sentence: <start> no es tan facil como la gente piensa . <end>
# Survival Voting_result:  it is isn is easy to as people think . <end>
# sentence: <start> no se como comprar un billete . <end>
# Survival Voting_result:  i don don t know how to buy a ticket . <end>
# sentence: <start> mi hobby es coleccionar estampillas . <end>
# Survival Voting_result:  my hobby is is stamps . <end>
# sentence: <start> ¿ cual es el siguiente paso que hay que dar ? <end>
# Survival Voting_result:  what is the the next piece you have to ? <end>
# sentence: <start> la frase siguiente es falsa . <end>
# Survival Voting_result:  the next person is counterfeit . <end>
# sentence: <start> esperare otros cinco minutos . <end>
# Survival Voting_result:  i will wait wait for five minutes . <end>
# sentence: <start> yo pienso que es demasiado arriesgado . <end>
# Survival Voting_result:  i think i i m too risky . <end>
# sentence: <start> nunca cuestionaria su honestidad . <end>
# no words!
# Survival Voting_result:  no word
# sentence: <start> los pasajeros se pusieron nerviosos cuando el avion comenzo a vibrar . <end>
# no words!
# Survival Voting_result:  no word
# sentence: <start> tengo que averiguar la verdad <end>
# Survival Voting_result:  i have to have the exact make a word . let s hope it s worth a word . <end>
# sentence: <start> ya he encontrado lo que estaba buscando . <end>
# Survival Voting_result:  i have ve already found what i was looking for . <end>
# sentence: <start> ahora le quiere mas que antes . <end>
# Survival Voting_result:  she now he is like more than before . <end>
# sentence: <start> esto es un harpa . <end>
# no words!
# Survival Voting_result:  no word
# sentence: <start> tal vez deberiamos esperar . <end>
# Survival Voting_result:  perhaps we we should wait . <end>
# sentence: <start> quiero una gominola . <end>
# no words!
# Survival Voting_result:  no word
# sentence: <start> tom se esta probando zapatos . <end>
# no words!
# Survival Voting_result:  no word
# sentence: <start> voy a estudiar mucho . <end>
# Survival Voting_result:  i am go going to study a lot . <end>
# sentence: <start> el esta seguro de su exito . <end>
# Survival Voting_result:  he is is sure of his success . <end>
# sentence: <start> tom volvio adentro . <end>
# Survival Voting_result:  tom went back back . <end>
# sentence: <start> el murio tras una larga enfermedad . <end>
# Survival Voting_result:  he died died after a long illness . <end>
# sentence: <start> contacte a mi hijo . <end>
# Survival Voting_result:  get my my son . <end>
# sentence: <start> se lo raro que es esto . <end>
# Survival Voting_result:  it was was like this is . <end>
# sentence: <start> soplaba un viento fuerte . <end>
# Survival Voting_result:  a wind wind a muslim . <end>
# sentence: <start> esta rota . <end>
# Survival Voting_result:  this broken broken . <end>
# sentence: <start> no queremos presionarte . <end>
# no words!
# Survival Voting_result:  no word
# sentence: <start> ¿ hay lugar para otra persona ? <end>
# Survival Voting_result:  is there there a person ? <end>
# sentence: <start> quiero ayudarte con los deberes . <end>
# Survival Voting_result:  i want want to help you with you . <end>
# sentence: <start> no nos gustan nuestros vecinos , y a ellos tampoco les gustamos nosotros . <end>
# Survival Voting_result:  we don don t like our neighbors , and follow them . <end>
# sentence: <start> para de hacer el vago y encuentra algo que hacer . <end>
# Survival Voting_result:  to make the make out and he is something to do . <end>
# sentence: <start> los pensamientos se expresan con palabras . <end>
# no words!
# Survival Voting_result:  no word
# sentence: <start> tom llamo a mary para decirle que podria necesitar su ayuda despues esa tarde . <end>
# Survival Voting_result:  tom called mary mary to tell her help her friends for that afternoon . <end>
# sentence: <start> un extranjero me pregunto en donde queda la estacion . <end>
# Survival Voting_result:  a a little little asked me where to the station . <end>
# sentence: <start> las polillas son atraidas por la luz . <end>
# no words!
# Survival Voting_result:  no word
# sentence: <start> deberiamos dejar descansar a los perros dormidos . <end>
# Survival Voting_result:  we should should have the dogs began . <end>
# sentence: <start> no se si queremos hacerlo . <end>
# Survival Voting_result:  i don don t know if we want to do it . <end>
# sentence: <start> creo que fue un malentendido . <end>
# Survival Voting_result:  i think i it was a misunderstanding . <end>
# sentence: <start> es tu deber terminar el trabajo . <end>
# Survival Voting_result:  it is is your duty to finish the work . <end>
# sentence: <start> ¿ me podrian dar un trozo de tarta de queso ? <end>
# Survival Voting_result:  could i have have a piece of cheesecake ? <end>
# sentence: <start> dile a tom que no estare alli . <end>
# Survival Voting_result:  tell tom tom tom not to go there . <end>
# sentence: <start> no hables con la boca llena . <end>
# Survival Voting_result:  don t t t on your mouth full . <end>
# sentence: <start> me costo conseguir una entrada para el concierto . <end>
# Survival Voting_result:  it took me a ticket to get the concert . <end>
# sentence: <start> nos vemos una vez por mes . <end>
# Survival Voting_result:  see you a once . <end>
# sentence: <start> es uno de los libros mas conocidos de la literatura brasilera . <end>
# no words!
# Survival Voting_result:  no word
# sentence: <start> tom y mary han estado divorciados por mas de tres anos . ¿ en serio ? no lo sabia . <end>
# Survival Voting_result:  tom and mary mary have been married for three years . <end>
# sentence: <start> tenemos que encontrar una nueva ninera . <end>
# Survival Voting_result:  we have to have a new dim . <end>
# sentence: <start> tenemos que prevenir a tom . <end>
# Survival Voting_result:  we have to to tom . <end>
# sentence: <start> se que todos ustedes son unos cobardes . <end>
# Survival Voting_result:  i know all you are all . <end>
# sentence: <start> ¿ puedes arrojar alguna luz en esto ? <end>
# Survival Voting_result:  can you you you ever put on this ? <end>
# sentence: <start> ¿ sabes como cocinar bien el arroz ? <end>
# Survival Voting_result:  do you you you how to cook playing the rice ? <end>
# sentence: <start> no queremos causar ningun problema . <end>
# Survival Voting_result:  we don don t want to cause any trouble . <end>
# sentence: <start> le puse algo de leche a mi cafe . <end>
# Survival Voting_result:  i put put some milk a cup of my coffee . <end>
# sentence: <start> este texto esta destinado a los principiantes . <end>
# Survival Voting_result:  this text is is bound to beginners . <end>
# sentence: <start> ¿ quien te conto la historia ? <end>
# Survival Voting_result:  who told you you ? <end>
# sentence: <start> le vemos todos los dias . <end>
# Survival Voting_result:  see you every every day . <end>
# sentence: <start> ellos no cederan . <end>
# no words!
# Survival Voting_result:  no word
# sentence: <start> tom estaba muy complacido con los resultados . <end>
# no words!
# Survival Voting_result:  no word
# sentence: <start> si no come , morira . <end>
# Survival Voting_result:  if you don don t eat , we ll die . <end>
# sentence: <start> ayudemonos los unos a los otros . <end>
# no words!
# Survival Voting_result:  no word
# sentence: <start> ¿ como sabes que tan dificil es ? <end>
# Survival Voting_result:  how do do you know that it works ? <end>
# sentence: <start> ella lo derroto . <end>
# Survival Voting_result:  she she gave paid him . <end>
# sentence: <start> ya conoces a la gente . <end>
# Survival Voting_result:  you know know people . <end>
# sentence: <start> tom , ¿ estas ahi ? <end>
# Survival Voting_result:  tom , is , there are there ? <end>
# sentence: <start> tenemos un cocinero excelente . <end>
# Survival Voting_result:  we have have a wide garden . <end>
# sentence: <start> me comi el queso . <end>
# Survival Voting_result:  i ate had had cheese . <end>
# sentence: <start> esta teoria es para mi demasiado dificil de entender . <end>
# Survival Voting_result:  this theory is is too difficult to understand . <end>
# sentence: <start> siempre me saque buenas notas en frances . <end>
# Survival Voting_result:  i always have always good remarks in french . <end>
# sentence: <start> no pudimos parar de reir . <end>
# Survival Voting_result:  we couldn couldn t stop giggling . <end>
# sentence: <start> tom fue a boston a visitar a su tio . <end>
# Survival Voting_result:  tom went to went to boston to his uncle . <end>
# sentence: <start> ayer vi television por dos horas . <end>
# Survival Voting_result:  i watched watched tv yesterday . <end>
# sentence: <start> ese viejo es muy chiqueado para la comida . <end>
# no words!
# Survival Voting_result:  no word
# sentence: <start> habla claramente . <end>
# Survival Voting_result:  he clearly clearly clearly . <end>
# sentence: <start> tengo que elegir entre esos dos . <end>
# Survival Voting_result:  i have to have between between these two . <end>
# sentence: <start> ¿ que es lo que haces ? <end>
# Survival Voting_result:  what what do do you doing ? <end>
# sentence: <start> el saco los huevos uno por uno . <end>
# Survival Voting_result:  he took took took out for a half . <end>
# sentence: <start> su carcajada hizo eco por toda la casa . <end>
# no words!
# Survival Voting_result:  no word
# sentence: <start> nunca me dijiste que tenias una hermana . <end>
# Survival Voting_result:  you never told told you just a sister . <end>
# sentence: <start> el hizo lo que le dijeron . <end>
# Survival Voting_result:  he did what he told him . <end>
# sentence: <start> tom le susurro algo a mary . <end>
# Survival Voting_result:  tom whispered something something . <end>
# sentence: <start> me gusta particularmente el olor de las lilas . <end>
# no words!
# Survival Voting_result:  no word
# sentence: <start> ¿ me prestas tu auto esta noche ? <end>
# Survival Voting_result:  can i i borrow your car tonight ? <end>
# sentence: <start> el gasto llego a doce pesos . <end>
# Survival Voting_result:  he got used used to twelve to face . <end>
# sentence: <start> no seas tan descuidado en tu trabajo . <end>
# Survival Voting_result:  don t t be too careless on your work . <end>
# sentence: <start> ven aqui y unetenos . <end>
# no words!
# Survival Voting_result:  no word
# sentence: <start> no puedo esperar para salir de vacaciones . <end>
# Survival Voting_result:  i can can can t go out on your holidays . <end>
# sentence: <start> nuestro partido de futbol sera pospuesto . <end>
# Survival Voting_result:  our football game game will take off your tongue . <end>
# sentence: <start> la tormenta destruyo toda la ciudad . <end>
# Survival Voting_result:  the storm war storm all the town . <end>
# sentence: <start> iba a usarlo . <end>
# Survival Voting_result:  i was was used to use it . <end>
# sentence: <start> esperame . <end>
# Survival Voting_result:  wait for me me . <end>
# sentence: <start> ¿ que lleva este guiso ? <end>
# Survival Voting_result:  what is is this type ? <end>
# sentence: <start> ¿ donde esta la pasta de dientes ? <end>
# Survival Voting_result:  where is the the experience s your teeth ? <end>
# sentence: <start> la chica que lleva un vestido blanco es mi hermana . <end>
# Survival Voting_result:  the girl girl girl is a white dress is my favorite . <end>
# sentence: <start> no olvides verme manana por la manana . <end>
# Survival Voting_result:  don t t t see me up early in the morning . <end>
# sentence: <start> no soy esclavo de tomas . <end>
# Survival Voting_result:  i m no not tom s car . <end>
# sentence: <start> estare afuera . <end>
# Survival Voting_result:  i will will be back . <end>
# sentence: <start> nos perdimos en el bosque . <end>
# Survival Voting_result:  we got lost got air in the forest . <end>
# sentence: <start> no tengo suficiente dinero para comprarlo . <end>
# Survival Voting_result:  i do have no money to buy it . <end>
# sentence: <start> el cuarto mes se llama abril . <end>
# Survival Voting_result:  the room next month . <end>
# sentence: <start> ella lo llama todas las noches y habla al menos una hora . <end>
# Survival Voting_result:  she calls calls him every night and she every night . <end>
# sentence: <start> adondequiera que vayas , conoceras gente amable y generosa . <end>
# Survival Voting_result:  wherever he he he ll come up , you guys make mistakes and it . <end>
# sentence: <start> dejad sitio ! <end>
# Survival Voting_result:  quit quit ! ! <end>
# sentence: <start> ¿ por que me llamaste ? <end>
# Survival Voting_result:  why did did you call me ? <end>
# sentence: <start> la mancha de tinta no se sale . <end>
# Survival Voting_result:  the sales sales sales will not come . <end>
# sentence: <start> no pienses que no lo intente . <end>
# Survival Voting_result:  i don don t think it won t try . <end>
# sentence: <start> tom tendra exito . <end>
# Survival Voting_result:  tom will will succeed . <end>
# sentence: <start> a tom se le hizo tarde . <end>
# Survival Voting_result:  tom did was was late . <end>
# sentence: <start> adoro el deporte . <end>
# Survival Voting_result:  i love love love . <end>
# sentence: <start> la meta es estar fuera del pais dentro de una hora . <end>
# Survival Voting_result:  the goal is is out of the country on time . <end>
# sentence: <start> se acabo . <end>
# Survival Voting_result:  i have just left . <end>
# sentence: <start> quiero que se vaya . <end>
# Survival Voting_result:  i want want you to go . <end>
# sentence: <start> no te muevas . <end>
# Survival Voting_result:  don t t t move . <end>
# sentence: <start> ¿ por que no estaban alli ? <end>
# Survival Voting_result:  why why didn were you there ? <end>
# sentence: <start> no respondio al telefono , asi que le mande un correo . <end>
# Survival Voting_result:  he didn didn t respond to the phone , so he sent a mail . <end>
# sentence: <start> yo no te di un regalo . <end>
# Survival Voting_result:  i didn don t give you a present . <end>
# sentence: <start> ¿ como suena eso ? <end>
# Survival Voting_result:  how does that that s that ? <end>
# sentence: <start> esta noche vamos al cine . <end>
# Survival Voting_result:  we go tonight go . <end>
# sentence: <start> vimos una momia en el museo . <end>
# no words!
# Survival Voting_result:  no word
# sentence: <start> ¿ en que momento estudias ? <end>
# Survival Voting_result:  what do do you study for ? <end>
# sentence: <start> ellos me miraban en silencio . <end>
# no words!
# Survival Voting_result:  no word
# sentence: <start> este es un gran proyecto . <end>
# Survival Voting_result:  this is is a great mission . <end>
# sentence: <start> el sabe hablar japones . <end>
# Survival Voting_result:  he he can can speak japanese . <end>
# sentence: <start> existe un grado de estres en todos los trabajos . <end>
# Survival Voting_result:  a ring a camping on everyone on their computer . <end>
# sentence: <start> una catastrofe ha sido impedida . <end>
# no words!
# Survival Voting_result:  no word
# sentence: <start> no sabia que hacer entonces . <end>
# Survival Voting_result:  i didn didn t know what to do that . <end>
# sentence: <start> me pregunto donde se estara escondiendo . <end>
# Survival Voting_result:  i i m wonder where he is hiding . <end>
# sentence: <start> estoy demasiado borracho . <end>
# Survival Voting_result:  i am am too drunk . <end>
# sentence: <start> ¿ le falta a usted algo en su cartera ? <end>
# Survival Voting_result:  do you you you in your wallet ? <end>
# sentence: <start> ¿ te gustaria un platano ? <end>
# Survival Voting_result:  would you like like this evening ? <end>
# sentence: <start> repeti mi nombre . <end>
# Survival Voting_result:  get my my my name . <end>
# sentence: <start> ella quisiera que el se pusiera en contacto con ella tan pronto como sea posible . <end>
# Survival Voting_result:  she she would would have to look in touch her as possible as possible . <end>
# sentence: <start> a todos le agradabas . <end>
# no words!
# Survival Voting_result:  no word
# sentence: <start> se dijo a si mismo , lo hare . <end>
# Survival Voting_result:  he said said , i ll do it . <end>
# sentence: <start> desenchufa la television y apaga la luz . <end>
# no words!
# Survival Voting_result:  no word
# sentence: <start> compre dos camisas de algodon . <end>
# Survival Voting_result:  i buy have two cotton shirt . <end>
# sentence: <start> mi padre va a ser operado . <end>
# no words!
# Survival Voting_result:  no word
# sentence: <start> busque el libro por una hora . <end>
# Survival Voting_result:  i looked have for the book for one hour . <end>
# sentence: <start> he recibido una buena oferta de trabajo . <end>
# Survival Voting_result:  i have received a good guys a job . <end>
# sentence: <start> papa normalmente viene a casa a las ocho . <end>
# Survival Voting_result:  father usually usually usually at eight . <end>
# sentence: <start> espera por mi aqui . <end>
# Survival Voting_result:  wait for for my own . <end>
# sentence: <start> el ano pasado pase tanto tiempo solo que casi se me olvido como comunicarme de una manera eficaz con los otros . <end>
# Survival Voting_result:  last year year , i was just as i could tell me . <end>
# sentence: <start> mejor que cerres el pico ! <end>
# no words!
# Survival Voting_result:  no word
# sentence: <start> se que puede ser duro . <end>
# Survival Voting_result:  i know it may be hard . <end>
# sentence: <start> ¿ por que no puedes explicar que estas haciendo ? <end>
# Survival Voting_result:  why can can t explain what you re doing ? <end>
# sentence: <start> hoy dia estoy realmente cansado . <end>
# Survival Voting_result:  i i am really tired today . <end>
# sentence: <start> ese muchacho no mostro ningun temor . <end>
# Survival Voting_result:  that boy boy doesn t suffer of no one . <end>
# sentence: <start> su padre le dejo la casa en su testamento . <end>
# Survival Voting_result:  his father father left her house upside down in his will . <end>
# sentence: <start> tom estaba feliz al respecto . <end>
# Survival Voting_result:  tom was was was angry . <end>
# sentence: <start> ¿ que tiene que ver eso conmigo ? <end>
# Survival Voting_result:  what do do you think of that with me ? <end>
# sentence: <start> estos libros facilitaran su trabajo . <end>
# no words!
# Survival Voting_result:  no word
# sentence: <start> ¿ ya has leido este libro ? <end>
# ...
# Survival Voting_result:  i am no no tired . <end>
# sentence: <start> ¿ tiene seguro medico ? <end>
# Survival Voting_result:  do you you have a doctor ? <end>
# sentence: <start> encontrar una solucion optima demorara un tiempo . <end>
# no words!
# Survival Voting_result:  no word
# sentence: <start> algunos estaban borrachos la mayor parte del tiempo . <end>
# Survival Voting_result:  some people were were lost their time . <end>
# sentence: <start> cristobal colon descubrio america . <end>
# Survival Voting_result:  columbus columbus discovered came in north america . <end>
# sentence: <start> a finales de agosto , las fuerzas aliadas tomaron paris . <end>
# no words!
# Survival Voting_result:  no word
# sentence: <start> vendre a verte el domingo a las tres de la tarde . <end>
# Survival Voting_result:  i will come come to the sunday evening . <end>
# sentence: <start> quiero que seas mi socio . <end>
# Survival Voting_result:  i want want you to be my advice . <end>
# sentence: <start> ella es amable . <end>
# Survival Voting_result:  she is is is . <end>
# sentence: <start> no esta de acuerdo con su familia . <end>
# Survival Voting_result:  he is doesn doesn t agree with his family . <end>
# sentence: <start> esta ocurriendo esta noche . <end>
# Survival Voting_result:  this is is going tonight . <end>
# sentence: <start> deberias haber llamado a la policia . <end>
# Survival Voting_result:  you should should ve taken the police . <end>
# sentence: <start> eres la ultima persona que habria pensado encontrar aqui . <end>
# Survival Voting_result:  you re the the person who d ve ever find it . <end>
# sentence: <start> esto no es un accidente . <end>
# Survival Voting_result:  this is isn isn t an accident . <end>
# sentence: <start> habeis venido demasiado pronto . <end>
# Survival Voting_result:  you have have arrived too early . <end>
# sentence: <start> dejo de buscar la perla . <end>
# no words!
# Survival Voting_result:  no word
# sentence: <start> le gusta cazar . <end>
# Survival Voting_result:  he is always is invited . <end>
# sentence: <start> no te olvides de despertarme manana por la manana . <end>
# Survival Voting_result:  don t t t forget to wake me tomorrow morning . <end>
# sentence: <start> tom decidio no decirle a maria nada de lo que juan habia hecho . <end>
# Survival Voting_result:  tom decided decided not to tell mary anything about what john had done . <end>
# sentence: <start> les di mil yenes a cada uno . <end>
# Survival Voting_result:  i gave a gave up , yen to one . <end>
# sentence: <start> pense que habias dicho que tom habia muerto . <end>
# Survival Voting_result:  i thought thought you said tom had dead . <end>
# sentence: <start> esta manana llegue tarde a la escuela . <end>
# Survival Voting_result:  i i will come to school this morning . <end>
# sentence: <start> el bebe esta llorando . <end>
# Survival Voting_result:  the baby is is crying . <end>
# sentence: <start> me quede atonito . <end>
# Survival Voting_result:  i was was exhausted . <end>
# sentence: <start> me gustaria tomar al menos una botella mas de cerveza antes de ir a casa . <end>
# Survival Voting_result:  i would like like to take a single more than you go home . <end>
# sentence: <start> una batidora te permite mezclar comidas diferentes . <end>
# no words!
# Survival Voting_result:  no word
# sentence: <start> tom le regalo un diccionario de frances a mary . <end>
# Survival Voting_result:  tom gave mary a french dictionary to mary . <end>
# sentence: <start> caminaba a paso rapido . <end>
# Survival Voting_result:  i was went was quickly . <end>
# sentence: <start> realmente funciona . <end>
# Survival Voting_result:  it really really works . <end>
# sentence: <start> los guardias dispersaron a la multitud . <end>
# no words!
# Survival Voting_result:  no word
# sentence: <start> no tengo un mango . <end>
# Survival Voting_result:  i don do t have any money . <end>
# sentence: <start> voy a hacer una pasantia en una empresa local . <end>
# no words!
# Survival Voting_result:  no word
# sentence: <start> dijo que ira a estados unidos . <end>
# Survival Voting_result:  he said he he go to america . <end>
# sentence: <start> el policia tenia una curda encima . . . <end>
# no words!
# Survival Voting_result:  no word
# sentence: <start> te dije que te quedaras quieta . <end>
# Survival Voting_result:  i i told told you to stay a lot . <end>
# sentence: <start> tom tiene que pagar por todo . <end>
# Survival Voting_result:  tom has to to pay for everything . <end>
# sentence: <start> ¿ que necesita decir tom para que mary lo perdone ? <end>
# Survival Voting_result:  what do do do you think tom to tell him to tell him to tell him to tell him to tell him to tell him to tell him to tell him to tell him to tell him to tell him to tell him to tell him to tell him to tell him to
# sentence: <start> ella ira a francia la semana proxima . <end>
# Survival Voting_result:  she will go go to france next week . <end>
# sentence: <start> tom y mary estan muy enamorados . <end>
# Survival Voting_result:  tom and mary and mary are very in love . <end>
# sentence: <start> ella estuvo inconsciente por tres dias . <end>
# Survival Voting_result:  she was she was three days . <end>
# sentence: <start> se lo que le paso a tom . <end>
# Survival Voting_result:  i know what what happened to tom . <end>
# sentence: <start> tom preparo una torta para el cumpleanos de mary . <end>
# Survival Voting_result:  tom made made a cake for mary s birthday . <end>
# sentence: <start> estoy almorzando con mi hermana ahora . <end>
# Survival Voting_result:  i am am eating with my sister now . <end>
# sentence: <start> ¿ por que quieres esto ? <end>
# Survival Voting_result:  why why do do you want this ? <end>
# sentence: <start> los estudiantes se levantaron uno por uno y se presentaron . <end>
# Survival Voting_result:  the students students students for one and took . <end>
# sentence: <start> estan hechos un manojo de nervios . <end>
# Survival Voting_result:  they re re made a nervous wreck . <end>
# sentence: <start> el ruido del trafico denso me mantuvo toda la noche despierto . <end>
# no words!
# Survival Voting_result:  no word
# sentence: <start> el gato me espanto . <end>
# no words!
# Survival Voting_result:  no word
# sentence: <start> es ella . <end>
# Survival Voting_result:  she is she is . <end>
# sentence: <start> el sorprendio a su adversario . <end>
# no words!
# Survival Voting_result:  no word
# sentence: <start> ayer me encontre con mary . <end>
# Survival Voting_result:  yesterday i i met mary yesterday . <end>
# sentence: <start> ¿ que prefieres , las manzanas o los platanos ? <end>
# Survival Voting_result:  which do do do you prefer , apples , are bad ? <end>
# sentence: <start> es italiano de nacimiento . <end>
# Survival Voting_result:  it is is s an anchor to me . <end>
# sentence: <start> creo que tom no tiene la capacidad de resolver el problema . <end>
# Survival Voting_result:  i think tom tom doesn t know how to solve the problem . <end>
# sentence: <start> no hablo hebreo . <end>
# Survival Voting_result:  i don t t heard a freak . <end>
# sentence: <start> este es mi colegio . <end>
# Survival Voting_result:  this is is my school . <end>
# sentence: <start> ¿ que mas quiere tom ? <end>
# Survival Voting_result:  what is more else ? <end>
# sentence: <start> parece estar muy feliz . <end>
# Survival Voting_result:  she seems seems very happy . <end>
# sentence: <start> la estas cagando . <end>
# Survival Voting_result:  you re re re not . <end>
# sentence: <start> tom no esperaba eso . <end>
# Survival Voting_result:  tom didn t didn t expect that . <end>
# sentence: <start> no puedo mentirte . <end>
# Survival Voting_result:  i can can t lie . <end>
# sentence: <start> no se que haremos . <end>
# Survival Voting_result:  i don don t know what we will do . <end>
# sentence: <start> no puedes ser amigo de todos . <end>
# Survival Voting_result:  you can can can be a friend of all . <end>
# sentence: <start> no estoy segura de que quiera el trabajo . <end>
# Survival Voting_result:  i am no no matter what you want the work . <end>
# sentence: <start> ¿ que puedes hacer por mi ? <end>
# Survival Voting_result:  what can can do for me ? <end>
# sentence: <start> muchos estudiantes buscan trabajos a tiempo parcial . <end>
# no words!
# Survival Voting_result:  no word
# sentence: <start> ¿ como lo sabes ? <end>
# Survival Voting_result:  how do do you know that ? <end>
# sentence: <start> lea estas instrucciones . <end>
# Survival Voting_result:  read these these these instructions . <end>
# sentence: <start> se necesita una llave para abrir la caja . <end>
# Survival Voting_result:  there is a a open to open the box . <end>
# sentence: <start> preguntame manana . <end>
# Survival Voting_result:  tomorrow , i will be tomorrow . <end>
# sentence: <start> el dinero no lo es todo , pero si no tienes dinero no puedes hacer nada . <end>
# Survival Voting_result:  money isn isn t everything , but you don t have accomplished . <end>
# sentence: <start> ¿ que me aconsejas hacer ? <end>
# Survival Voting_result:  what do do you advise me to do ? <end>
# sentence: <start> no deberias usar ropa ajustada si estas embarazada . <end>
# Survival Voting_result:  you shouldn shouldn shouldn t wear clothes for these attention . <end>
# sentence: <start> los dos ninos empezaron a culparse el uno al otro . <end>
# no words!
# Survival Voting_result:  no word
# sentence: <start> ella vivio alli durante muchos anos . <end>
# Survival Voting_result:  she she lived lived for many years . <end>
# sentence: <start> el no es el tipo mas listo de la clase . <end>
# Survival Voting_result:  he isn isn isn t the tallest one of the class . <end>
# sentence: <start> esta no sera la ultima vez . <end>
# Survival Voting_result:  this is not not the last time . <end>
# sentence: <start> el acaba de comprarse un coche usado . <end>
# Survival Voting_result:  he just just just a used car . <end>
# sentence: <start> despues de conferenciar varias horas hicieron publicos los acuerdos . <end>
# no words!
# Survival Voting_result:  no word
# sentence: <start> no puedo creer que tom no venga . <end>
# Survival Voting_result:  i can can t believe tom won t come . <end>
# sentence: <start> ¿ que te pareceria una taza de te u otra cosa , si es que no estas apurado ? <end>
# no words!
# Survival Voting_result:  no word
# sentence: <start> el millonario tenia la intencion de adquirir la obra maestra sin importar lo que costara . <end>
# Survival Voting_result:  the millionaire had had a suspicion of the little money he will cost . <end>
# sentence: <start> le dare todo lo que necesite . <end>
# Survival Voting_result:  i will give give him what he needs . <end>
# sentence: <start> las negociaciones naufragaron . <end>
# no words!
# Survival Voting_result:  no word
# sentence: <start> el ha traicionado a sus amigos por dinero . <end>
# Survival Voting_result:  he has has betrayed his friends for money . <end>
# sentence: <start> vamos a tener un bebe . <end>
# Survival Voting_result:  we re have have a baby . <end>
# sentence: <start> tom parece preocupado . <end>
# Survival Voting_result:  tom seems seems worried . <end>
# sentence: <start> continue su analisis . <end>
# no words!
# Survival Voting_result:  no word
# sentence: <start> el suele ser arrogante . <end>
# Survival Voting_result:  he is often is arrogant . <end>
# sentence: <start> tom tiene un fuerte resfriado . <end>
# Survival Voting_result:  tom has has a bad cold . <end>
# sentence: <start> tom no tiene tiempo para ayudarte . <end>
# Survival Voting_result:  tom doesn doesn t have time to help you . <end>
# sentence: <start> querria un poco de queso . <end>
# Survival Voting_result:  i would would like some milk . <end>
# sentence: <start> no podria haberlo expresado mejor . <end>
# Survival Voting_result:  i could could have studied how much better . <end>
# sentence: <start> ¿ por que estas tan seguro de que tom es canadiense ? <end>
# Survival Voting_result:  why are you you sure tom is canadian ? <end>
# sentence: <start> el maestro le leyo un parrafo de la biblia a la clase . <end>
# Survival Voting_result:  the teacher teacher teacher for the bible at the key to the class . <end>
# sentence: <start> tom fue herido . <end>
# Survival Voting_result:  tom was was hurt . <end>
# sentence: <start> tu tienes prohibido fumar aqui . <end>
# Survival Voting_result:  you are are under these here . <end>
# sentence: <start> quiero estar contigo pase lo que pase . <end>
# Survival Voting_result:  i want want to be with you by myself . <end>
# sentence: <start> todos miramos por la ventana . <end>
# Survival Voting_result:  everybody looked all looked back . <end>
# sentence: <start> no podia dar otra mordida . <end>
# Survival Voting_result:  i couldn couldn t give it again . <end>
# sentence: <start> un doctor puede enterrar sus errores , pero un arquitecto solo puede sugerirle a su cliente plantar enredaderas . <end>
# no words!
# Survival Voting_result:  no word
# sentence: <start> ¿ cual es tu desayuno preferido ? <end>
# Survival Voting_result:  what is your your favorite breakfast ? <end>
# sentence: <start> la temperatura bajo . <end>
# Survival Voting_result:  the temperature temperature temperature . <end>
# sentence: <start> no sali a ningun lado porque tu me dijiste que no lo hiciera . <end>
# Survival Voting_result:  i didn t t beat you because you told me to me to . <end>
# sentence: <start> tom alego ser el hijo de mary . <end>
# Survival Voting_result:  tom tom was was the son s son . <end>
# sentence: <start> los cables transmiten la electricidad . <end>
# Survival Voting_result:  the cables the cables . <end>
# sentence: <start> el rechazo su solicitud de un dia libre . <end>
# Survival Voting_result:  he turned turned down on a day off . <end>
# sentence: <start> por favor , ¿ podria firmar este documento ? <end>
# Survival Voting_result:  please could you this sign this project ? <end>
# sentence: <start> he oido que eres una buena jugadora de tenis . <end>
# no words!
# Survival Voting_result:  no word
# sentence: <start> tomo vitaminas todos los dias . <end>
# Survival Voting_result:  it take take off every day . <end>
# sentence: <start> salio de la habitacion . <end>
# Survival Voting_result:  she left came out of the room . <end>
# sentence: <start> ¿ tomas estaba aqui cuando paso ? <end>
# Survival Voting_result:  was tom here here happened ? <end>
# sentence: <start> pase toda la tarde tratando de encontrar mis llaves . <end>
# Survival Voting_result:  i spent all all evening trying to find my keys . <end>
# sentence: <start> solo queria decirte que me he encontrado con tom esta manana . <end>
# Survival Voting_result:  i just just just told tom this morning . <end>
# sentence: <start> ¿ crees que es justo ? <end>
# Survival Voting_result:  do you you you re the idea ? <end>
# sentence: <start> llama a mi esposo ! <end>
# Survival Voting_result:  call my my my grip on me . <end>
# sentence: <start> el estaba de buen humor . <end>
# Survival Voting_result:  he was was in a good mood . <end>
# sentence: <start> tengo ganas de salir hoy en lugar de quedarme en casa . <end>
# Survival Voting_result:  i feel feel like eating right now . <end>
# sentence: <start> rendirse no es la respuesta . <end>
# Survival Voting_result:  it isn isn isn t the answer . <end>
# sentence: <start> nosotros comemos langostas solo en ocasiones especiales . <end>
# no words!
# Survival Voting_result:  no word
# sentence: <start> tomas volvera pronto . <end>
# Survival Voting_result:  tom will will come back . <end>
# sentence: <start> esta casa necesita una mano de pintura . <end>
# Survival Voting_result:  this house is is full of painting . <end>
# sentence: <start> mi padre esta ocupado escribiendo cartas . <end>
# Survival Voting_result:  my father father is busy writing . <end>
# sentence: <start> te vere manana en la biblioteca . <end>
# Survival Voting_result:  see you you you in the library tomorrow . <end>
# sentence: <start> el me dejo esperando . <end>
# Survival Voting_result:  he he let let me waiting for me . <end>
# sentence: <start> la profesora la trato como una mas de sus estudiantes . <end>
# Survival Voting_result:  the teacher teacher only one more than her students . <end>

# %%
# translate(u'esta es mi vida.')  # this is my life
# Out:
# sentence: <start> esta es mi vida . <end>
# Survival Voting_result:  this is is my life . <end>
# 'this is is my life . <end> '

# %%
# translate(u'hace mucho frio aqui.')  # it s very cold here
# Out:
# sentence: <start> hace mucho frio aqui . <end>
# Survival Voting_result:  it is very cold here . <end>
# 'it is very cold here . <end> '

# %%
# translate(u'¿todavia estan en casa?')  # Are you still at home?
# Out:
# sentence: <start> ¿ todavia estan en casa ? <end>
# Survival Voting_result:  are you still still ? <end>
# 'are you still still ? <end> '

# %%
# translate(u'¿Con quién desea hablar?')  # Who do you want to talk to?
# Out:
# sentence: <start> ¿ con quien desea hablar ? <end>
# Survival Voting_result:  who do do you want to speak to ? <end>
# 'who do do you want to speak to ? <end> '
